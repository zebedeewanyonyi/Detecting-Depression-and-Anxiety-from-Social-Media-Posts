# %%
# import libraries
import pandas as pd
import numpy as np

# libraries for data preprocessing
import nltk
#for tokenization
from nltk.tokenize import word_tokenize
#for lemmatisation
from nltk.stem import WordNetLemmatizer
# download modules available with NLTK
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
from sklearn.model_selection import train_test_split
# libraries for data plotting
import seaborn as sns
import matplotlib.pyplot as plt

RANDOM_SEED = 100
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# load the data set
df = pd.read_csv('/content/drive/MyDrive/Mental-health-related-subreddits.csv')

print(df.shape)
df.head()
# Out:
# (488472, 3)
#                                                Title  \
# 0                            exposure does not work!
# 1  Panic attack? derealization? can't go to docto...
# 2                 How long can a panic attack last?!
# 3                                    Stepping stones
# 4  Coping with anxiety over climate change, on th...
#
#                                                 Text Subreddit
# 0  I have struggled with social anxiety from chil...   Anxiety
# 1  Back in March (I know, a while ago D:), I woke...   Anxiety
# 2  I've been withdrawing from medicines lately (e...   Anxiety
# 3  First time poster, long time lurker. \n\nI've ...   Anxiety
# 4  Hi all,\n\nI made a throwaway account as my ma...   Anxiety

# %%
#filter out the mental health labels required
anxiety=df[df['Subreddit']=='Anxiety']
depression=df[df['Subreddit']=='depression']

# %%
#select 10000 records for each mental health problem
anxiety=anxiety.sample(n=10000)
depression=depression.sample(n=10000)

# %%
anxiety
# Out:
#                                                    Title  \
# 1183   DAE feel like their anxiety is trying to sabot...
# 33359             Should Gabapentin be a scheduled drug?
# 77926              Activities to "slow down" life a bit.
# 18724                         School made me cry all day
# 4331                              Vent: Just overwhelmed
# ...                                                  ...
# 23153                            Anxiety kicked in again
# 80563                              Anxiety from a Dream?
# 56630  Laptop: Password incorrect. Me: Have I been fi...
# 17482      anxiety about upcoming festival i'm attending
# 78674                                 Smoking Cigarettes
#
#                                                     Text Subreddit
# 1183   I know this is a super run-of-the-mill thing t...   Anxiety
# 33359  I’m torn on this issue because while its a rat...   Anxiety
# 77926  I do apologise if the title of this post sound...   Anxiety
# 18724  Its an emergency. I cried all day and told my ...   Anxiety
# 4331   I am new here, so if this violates policy, I a...   Anxiety
# ...                                                  ...       ...
# 23153  Background: \nThis summer I (M-19) was lucky t...   Anxiety
# 80563  Last night I had an incredibly intense fearful...   Anxiety
# 56630                    Why do you do this to me brain?   Anxiety
# 17482  I dated this girl on and off for about five ye...   Anxiety
# 78674  Ever since I took up smoking cigarettes, it se...   Anxiety
#
# [10000 rows x 3 columns]

# %%
depression
# Out:
#                                                     Title  \
# 292377           Thinking the thought of someone about me
# 136172                            My life is meaningless.
# 370793                            Work related depression
# 228977                    Desperate for help &amp; advice
# 131386                                          Scheduled
# ...                                                   ...
# 177838  How did people with depression and recluses co...
# 166536                             Mom, I love you but...
# 327950                                  What's the point?
# 370033                      i hope everyone is doing okay
# 154979    I've hit the rut that not even therapy can fix.
#
#                                                      Text   Subreddit
# 292377  I was about to write 4 paragraph wall of text ...  depression
# 136172  I can't take this anymore. I'm borderline fail...  depression
# 370793  I've only been at my current job 6 months but ...  depression
# 228977  I have a friend that has depression and anxiet...  depression
# 131386  Finally had a shrink appointment scheduled thi...  depression
# ...                                                   ...         ...
# 177838  Don't get me wrong,social media has its down s...  depression
# 166536  You are killing me with all the guilt. You are...  depression
# 327950  I'll be honest, my life is not the worst. I am...  depression
# 370033  i hope you were able to get through the day to...  depression
# 154979  Burner account for this obviously. I have no f...  depression
#
# [10000 rows x 3 columns]

# %%
#combine the dataframes to 1 dataframe
frames=[anxiety,depression]
df=pd.concat(frames)

# %%
df = pd.read_csv('/content/drive/MyDrive/subreddits.csv')

# %%
sns.countplot(x=df['Subreddit'])
# Out:
# <Axes: xlabel='Subreddit', ylabel='count'>

# %%
df = df.dropna()

print(f'Number of entries: {len(df)}')
# Out:
# Number of entries: 20000

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Tokenisation
# Using word_tokenize since its normal text

# %%
# run thru each record in the text columm and convert text to tokens
tokenized_text = [word_tokenize(text) for text in df['Text']]
#join the text into sentences using method join
tokenized_sentences = [' '.join(tokens) for tokens in tokenized_text]

# creating a new column in the dataframe with the tokenized sentences
df['Tokenized_Text'] = tokenized_sentences
df.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0       57177     Does it feel like your brain "short circuits"?
# 1       22650  Does anyone else feel comforted by lying on th...
# 2       41037                               Anxiety about Hentai
# 3       36212      Trying to do my best - unsure if an obsession
# 4        3390  How do I get over my fear of driving/ getting ...
#
#                                                 Text Subreddit  \
# 0  This has happened once before, only during a p...   Anxiety
# 1  When I'm really anxious, a lot of times my ins...   Anxiety
# 2  Hey,\n\nI know this may seem completely odd fo...   Anxiety
# 3  I’ve been diagnosed with GAD for quite sometim...   Anxiety
# 4  I live in Ohio and I would like to learn how t...   Anxiety
#
#                                       Tokenized_Text
# 0  This has happened once before , only during a ...
# 1  When I 'm really anxious , a lot of times my i...
# 2  Hey , I know this may seem completely odd for ...
# 3  I ’ ve been diagnosed with GAD for quite somet...
# 4  I live in Ohio and I would like to learn how t...

# %% [markdown]
# ### Normalizing Text
# I will use lemmatisation as opposed to stemming as it produces more accurate results representing the base word

# %%
lemmtizer = WordNetLemmatizer()

lemmatized_sentences = []

# iterate through each list of tokens and lemmatise the tokens
for tokens in tokenized_text:
  lemma_words = [lemmtizer.lemmatize(word) for word in tokens]
  lemma_sentence = ' '.join(lemma_words)
  lemmatized_sentences.append(lemma_sentence)

print(lemmatized_sentences[:2])

# add new column to data frame
df['Lemmatized_Text'] = lemmatized_sentences

df
# Out:
# ["This ha happened once before , only during a panic attack , but it happened last night when I had a really awful headache . I close my eye , try to go to sleep , or at the very least relax , and then it happens . My thought start racing , but so quickly that they make no sense . It 's sometimes beyond noneensical , and since I 'm not consciously thinking these strange thought , the only way they make sense ( at least while describing it ) is that these thought are n't my own .", "When I 'm really anxious , a lot of time my instinct is to lay on my bedroom floor . Even if I 'm in my bed , I will get out and lay on the floor . DAE experience this or know why this is ?"]
#        Unnamed: 0                                              Title  \
# 0           57177     Does it feel like your brain "short circuits"?
# 1           22650  Does anyone else feel comforted by lying on th...
# 2           41037                               Anxiety about Hentai
# 3           36212      Trying to do my best - unsure if an obsession
# 4            3390  How do I get over my fear of driving/ getting ...
# ...           ...                                                ...
# 19995      241131                                               Pain
# 19996      204328  Some word vomit about sexual abuse - feat. sel...
# 19997      237420  I’m at a crossroads after making several quest...
# 19998      334189   Does your depression push you forward like this?
# 19999      291767                 I feel like I'm shit at everything
#
#                                                     Text   Subreddit  \
# 0      This has happened once before, only during a p...     Anxiety
# 1      When I'm really anxious, a lot of times my ins...     Anxiety
# 2      Hey,\n\nI know this may seem completely odd fo...     Anxiety
# 3      I’ve been diagnosed with GAD for quite sometim...     Anxiety
# 4      I live in Ohio and I would like to learn how t...     Anxiety
# ...                                                  ...         ...
# 19995  I've severe depression for about 4 years now.\...  depression
# 19996  First of all, to summarize my feelings, a post...  depression
# 19997  I had a really really amazing job in a city I’...  depression
# 19998  When I was 15 I began to fall into my own hell...  depression
# 19999  I feel like I can't do anything right. I feel ...  depression
#
#                                           Tokenized_Text  \
# 0      This has happened once before , only during a ...
# 1      When I 'm really anxious , a lot of times my i...
# 2      Hey , I know this may seem completely odd for ...
# 3      I ’ ve been diagnosed with GAD for quite somet...
# 4      I live in Ohio and I would like to learn how t...
# ...                                                  ...
# 19995  I 've severe depression for about 4 years now ...
# 19996  First of all , to summarize my feelings , a po...
# 19997  I had a really really amazing job in a city I ...
# 19998  When I was 15 I began to fall into my own hell...
# 19999  I feel like I ca n't do anything right . I fee...
#
#                                          Lemmatized_Text
# 0      This ha happened once before , only during a p...
# 1      When I 'm really anxious , a lot of time my in...
# 2      Hey , I know this may seem completely odd for ...
# 3      I ’ ve been diagnosed with GAD for quite somet...
# 4      I live in Ohio and I would like to learn how t...
# ...                                                  ...
# 19995  I 've severe depression for about 4 year now ....
# 19996  First of all , to summarize my feeling , a pos...
# 19997  I had a really really amazing job in a city I ...
# 19998  When I wa 15 I began to fall into my own hell ...
# 19999  I feel like I ca n't do anything right . I fee...
#
# [20000 rows x 6 columns]

# %% [markdown]
# Spliting Dataset into train and test
#
# Split the raw data, tokenized and lemmatized data so that i can run experiments and compare the effects of each preprocessing techniques

# %%
#  raw text split
X_train_text, X_val_text, y_train, y_val = train_test_split(df['Text'], df['Subreddit'], test_size=0.3, random_state=42)

# tokenized text split
X_train_tokenized_text, X_val_tokenized_text, y_train, y_val = train_test_split(df['Tokenized_Text'], df['Subreddit'], test_size=0.3, random_state=42)


# lemmatised text split
X_train_lemmatized_text, X_val_lemmatized_text, y_train, y_val = train_test_split(df['Lemmatized_Text'], df['Subreddit'], test_size=0.3, random_state=42)

# %% [markdown]
# ### Classifiers (SVM, Naive Bayes, Logistic Regression)
# Logistic Regression (raw text split)

# %%
# libraries for ML algorithms
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB

#metrics and confusion matrix plot
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,ConfusionMatrixDisplay
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()  # default: lowercase=True, ngram_range=(1,1)
vectorizer.fit(X_train_text)

# convert train and test text data to numeric vectors
X_train = vectorizer.transform(X_train_text)
X_val = vectorizer.transform(X_val_text)

# %%
# build model
classifier1 = LogisticRegression()
classifier1.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on test data
y_pred = classifier1.predict(X_val)

# evalution
cm = confusion_matrix(y_val, y_pred)
ConfusionMatrixDisplay(cm, display_labels=classifier1.classes_).plot()
accuracy_sc=accuracy_score(y_val, y_pred)
print(accuracy_sc)
# Get best hyperparameters
# Out:
# 0.867

# %% [markdown]
# Logistic Regression (tokenized text split)

# %%
vectorizer = TfidfVectorizer()  # default: lowercase=True, ngram_range=(1,1)
vectorizer.fit(X_train_tokenized_text)

# convert train and test text data to numeric vectors
X_train2 = vectorizer.transform(X_train_tokenized_text)
X_val2 = vectorizer.transform(X_val_tokenized_text)

# %%
 # build model
classifier2 = LogisticRegression()
classifier2.fit(X_train2, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on test data
y_pred = classifier2.predict(X_val2)

# evalution
cm = confusion_matrix(y_val, y_pred)
ConfusionMatrixDisplay(cm, display_labels=classifier2.classes_).plot()
accuracy_sc=accuracy_score(y_val, y_pred)
print(accuracy_sc)
# Out:
# 0.8676666666666667

# %% [markdown]
# Logistic Regression (lemmatized text split)

# %%
vectorizer = TfidfVectorizer()  # default: lowercase=True, ngram_range=(1,1)
vectorizer.fit(X_train_lemmatized_text)

# convert train and test text data to numeric vectors
X_train3 = vectorizer.transform(X_train_lemmatized_text)
X_val3 = vectorizer.transform(X_val_lemmatized_text)

# %%
 # build model
classifier3 = LogisticRegression()
classifier3.fit(X_train3, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on test data
y_pred = classifier3.predict(X_val3)

# evalution
cm = confusion_matrix(y_val, y_pred)
ConfusionMatrixDisplay(cm, display_labels=classifier3.classes_).plot()
accuracy_sc=accuracy_score(y_val, y_pred)
print(accuracy_sc)
# Out:
# 0.8711666666666666
